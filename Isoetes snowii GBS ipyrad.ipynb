# %%
import ipyrad.analysis as ipa
import pandas as pd
import toyplot

# %%
# the path to your .snps.hdf5 database file
data = "~/Documents/Box/Isoetes/GBS/Broxton-strict.snps.hdf5"

# %%
# group individuals into populations
imap = {
    "Diploid": ["Ricketson_Tract_SW_4", "South_of_Sawdust_4", "Flat_Tub_789_3", "Flat_Tub_789_2", "Flat_Tub_789_1", "Corbitt_Tract_Mid_5", "Ricketson_Tract_SW_3", "Flat_Tub_789_4", "Corbitt_Tract_Mid_2", "Corbitt_Tract_Mid_4", "Flat_Tub_789_5", "South_of_Sawdust_3", "Ricketson_Tract_SW_1", "Ricketson_Tract_SW_5", "South_of_Sawdust_7", "Corbitt_Tract_Mid_1", "Ricketson_Tract_SW_2"],
    "Triploid": ["Corbitt_Tract_8", "Corbitt_Tract_10", "Corbitt_Tract_Mid_3", "Corbitt_Tract_11", "South_of_Sawdust_10", "South_of_Sawdust_9"],
    "Tetraploid": ["Flat_Tub_13_S_4", "Corbitt_Tract_1", "Flat_Tub_13_S_6", "Flat_Tub_13_S_2", "Flat_Tub_13_S_5", "Corbitt_Tract_12", "Arch_Cave_East_2", "Arch_Cave_East_5", "Arch_Cave_East_1", "Arch_Cave_East_4"],
}

# require that 50% of samples have data in each group
minmap = {i: 0.50 for i in imap}

# %%
print(minmap)
# Out:
# {'Diploid': 0.5, 'Triploid': 0.5, 'Tetraploid': 0.5}

# %%
# init pca object with input data and (optional) parameter options
pca = ipa.pca(
    data=data,
    imap=imap,
    minmap=minmap,
    mincov=0.9,
    impute_method="sample",
)
# Out:
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 167500
# Filtered (minmap): 159134
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 170261
# Sites after filtering: 24968
# Sites containing missing values: 19360 (77.54%)
# Missing values in SNP matrix: 79585 (9.66%)
# SNPs (total): 24968
# SNPs (unlinked): 4072
# Imputation: 'sampled'; (0, 1, 2) = 79.9%, 14.5%, 5.6%

# %%
# run the PCA analysis
pca.run()
# Out:
# Subsampling SNPs: 4072/24968

# %%
# store the PC axes as a dataframe
df = pd.DataFrame(pca.pcaxes[0], index=pca.names)

# write the PC axes to a CSV file
df.to_csv("pca_analysis.csv")

# show the first ten samples and the first 10 PC axes
df.iloc[:10, :10].round(2)
# Out:
#                          0     1      2     3      4     5     6     7      8  \
# Arch_Cave_East_1     18.98 -4.59  -5.08  1.43 -10.05  0.55 -1.43  0.19  -1.24
# Arch_Cave_East_2     19.85 -6.50  -6.11  1.51 -12.31  0.41 -2.57  0.72  -1.64
# Arch_Cave_East_4     19.98 -5.81  -6.45  1.68 -12.32  0.28 -1.43  1.20  -2.73
# Arch_Cave_East_5     20.54 -6.34  -6.46  1.31 -12.88 -0.22 -2.50  1.09  -1.92
# Corbitt_Tract_1      18.02 -6.96  -2.88 -0.08   5.79 -3.00 -3.82 -4.09  10.49
# Corbitt_Tract_10      8.51 -6.21   0.35 -0.63  12.14 -3.07 -4.76  4.07  -8.90
# Corbitt_Tract_11      8.89 -7.59   0.48 -0.75  13.64 -2.49 -4.00  2.28  -7.15
# Corbitt_Tract_12     17.82 -6.59  -2.79 -0.61   6.49 -2.34 -4.88 -2.00   5.14
# Corbitt_Tract_8       9.30 -7.99  -0.86 -0.67  11.82 -0.66 -3.55 -0.03  -2.95
# Corbitt_Tract_Mid_1 -13.68 -7.64  14.94 -5.41  -4.01 -3.24  0.02 -0.95   0.05
#
#                         9
# Arch_Cave_East_1     0.40
# Arch_Cave_East_2     0.90
# Arch_Cave_East_4     0.73
# Arch_Cave_East_5     0.86
# Corbitt_Tract_1     -4.57
# Corbitt_Tract_10     4.60
# Corbitt_Tract_11     4.01
# Corbitt_Tract_12    -1.85
# Corbitt_Tract_8     -1.01
# Corbitt_Tract_Mid_1 -0.64

# %%
# plot PC axes 0 and 1
pca.draw(0, 1);
# Out:
# <div class="toyplot" id="t2ea3f8f9ac414a24baaaaa695a438601" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t28e7e4aac3b143cf9a9d16d8e8d96596"><g class="toyplot-coordinates-Cartesian" id="td2d40eb3c96f44538b2f7b829cc183b1"><clipPath id="t64c926bc342a4773895b66f6a0cf2009"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t64c926bc342a4773895b66f6a0cf2009)"><g class="toyplot-mark-Point" id="tff1b3e95c67b4351a9b46f9b01f0df16"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(264.65201376851064, 221.81950715770023)"><title>Arch_Cave_East_1</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(270.0, 227.4472308658313)"><title>Arch_Cave_East_2</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(268.7755606161035, 228.0459608965342)"><title>Arch_Cave_East_4</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(268.904189718925, 231.62763615430407)"><title>Arch_Cave_East_5</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(266.1233881676809, 230.44881301985555)"><title>Corbitt_Tract_1</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(206.02071063949748, 231.6880371590675)"><title>Corbitt_Tract_10</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(208.29197507800683, 231.45234301630316)"><title>Corbitt_Tract_11</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(265.46675798855244, 232.9356194421976)"><title>Corbitt_Tract_12</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(206.99774649635395, 234.9537144221867)"><title>Corbitt_Tract_8</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(76.90932187192261, 216.79750619630164)"><title>Corbitt_Tract_Mid_1</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(80.26208187489745, 211.83911268282876)"><title>Corbitt_Tract_Mid_2</title><circle r="5.0"></circle>< ...

# %%
# plot PC axes 0 and 1 with no subsampling
pca.run(subsample=False)
pca.draw(0, 1);
# Out:
# <div class="toyplot" id="tbaf8ae736bbb430ead6d7cd31a81349d" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tced1a05d255744db832cf39b50d17a12"><g class="toyplot-coordinates-Cartesian" id="t16c4bea3396a4e84af5ebc17e89edb5b"><clipPath id="t7aaa516a76874c7e90fd4a5a4c8e4271"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t7aaa516a76874c7e90fd4a5a4c8e4271)"><g class="toyplot-mark-Point" id="t647d34ea3a804e088f8d7add396bb841"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(264.65201376851064, 221.81950715770023)"><title>Arch_Cave_East_1</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(270.0, 227.4472308658313)"><title>Arch_Cave_East_2</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(268.7755606161035, 228.0459608965342)"><title>Arch_Cave_East_4</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(268.904189718925, 231.62763615430407)"><title>Arch_Cave_East_5</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(266.1233881676809, 230.44881301985555)"><title>Corbitt_Tract_1</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(206.02071063949748, 231.6880371590675)"><title>Corbitt_Tract_10</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(208.29197507800683, 231.45234301630316)"><title>Corbitt_Tract_11</title><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(265.46675798855244, 232.9356194421976)"><title>Corbitt_Tract_12</title><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(206.99774649635395, 234.9537144221867)"><title>Corbitt_Tract_8</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(76.90932187192261, 216.79750619630164)"><title>Corbitt_Tract_Mid_1</title><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(80.26208187489745, 211.83911268282876)"><title>Corbitt_Tract_Mid_2</title><circle r="5.0"></circle>< ...

# %%
# plot PC axes 0 and 1 with many replicate subsamples
pca.run(nreplicates=25, seed=12345)
pca.draw(0, 1);
# Out:
# Subsampling SNPs: 4072/24968
# <div class="toyplot" id="t3bd22b07853149cf8c11f3acc4e1c8bd" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="td55390be78cf47e183d0897cc32e2450"><g class="toyplot-coordinates-Cartesian" id="tba6ececcb1434a4389339af43a99d217"><clipPath id="t674d6ec9732e4fbfb6725f18d41024cb"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t674d6ec9732e4fbfb6725f18d41024cb)"><g class="toyplot-mark-Point" id="t8eb91c3a6ff342d3aa399a8d25568ba5"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(265.3588924604359, 202.66967674780102)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(267.761583319615, 213.63219273419392)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(267.91814232152655, 208.54733114767348)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(268.85725126131047, 214.96401765952663)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(261.6586803624142, 221.18626453528717)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(208.422099191307, 221.98301798248988)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(208.93859391444448, 223.09554933012097)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(261.39583523232415, 220.02883119336653)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(207.9658442056607, 225.24250291905702)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(81.32270683708522, 227.2510984661357)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(82.52265144881322, 221.5488821883814)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(199.34781253193972, 241.7770628034837)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(79.76674429640367, 222.59887724564678)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(76.09537189643578, 227.22229990508987)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform= ...

# %%
### kmeans imputation
pca3 = ipa.pca(
    data=data,
    imap=imap,
    minmap=minmap,
    mincov=0.5,
    impute_method=3,
)
# Out:
# Kmeans clustering: iter=0, K=3, mincov=0.9, minmap={'global': 0.5}
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 179658
# Filtered (minmap): 140479
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 180788
# Sites after filtering: 14441
# Sites containing missing values: 8833 (61.17%)
# Missing values in SNP matrix: 16464 (3.45%)
# SNPs (total): 14441
# SNPs (unlinked): 2540
# Imputation: 'sampled'; (0, 1, 2) = 80.1%, 17.1%, 2.9%
# {0: ['Corbitt_Tract_Mid_1', 'Corbitt_Tract_Mid_2', 'Corbitt_Tract_Mid_4', 'Corbitt_Tract_Mid_5', 'Flat_Tub_789_1', 'Flat_Tub_789_2', 'Flat_Tub_789_3', 'Flat_Tub_789_4', 'Flat_Tub_789_5', 'Ricketson_Tract_SW_1', 'Ricketson_Tract_SW_2', 'Ricketson_Tract_SW_3', 'Ricketson_Tract_SW_4', 'Ricketson_Tract_SW_5', 'South_of_Sawdust_3', 'South_of_Sawdust_4', 'South_of_Sawdust_7'], 1: ['Arch_Cave_East_1', 'Arch_Cave_East_2', 'Arch_Cave_East_4', 'Arch_Cave_East_5', 'Corbitt_Tract_1', 'Corbitt_Tract_10', 'Corbitt_Tract_11', 'Corbitt_Tract_12', 'Corbitt_Tract_8', 'Corbitt_Tract_Mid_3', 'South_of_Sawdust_10', 'South_of_Sawdust_9'], 2: ['Flat_Tub_13_S_2', 'Flat_Tub_13_S_4', 'Flat_Tub_13_S_5', 'Flat_Tub_13_S_6']}
#
# Kmeans clustering: iter=1, K=3, mincov=0.8, minmap={0: 0.5, 1: 0.5, 2: 0.5}
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 172578
# Filtered (minmap): 161388
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 174903
# Sites after filtering: 20326
# Sites containing missing values: 14718 (72.41%)
# Missing values in SNP matrix: 46100 (6.87%)
# SNPs (total): 20326
# SNPs (unlinked): 3398
# Imputation: 'sampled'; (0, 1, 2) = 80.4%, 14.3%, 5.3%
# {0: ['Arch_Cave_East_1', 'Arch_Cave_East_2', 'Arch_Cave_East_4', 'Arch_Cave_East_5', 'Corbitt_Tract_1', 'Corbitt_Tract_10', 'Corbitt_Tract_11', 'Corbitt_Tract_12', 'Corbitt_Tract_8', 'Corbitt_Tract_Mid_3', 'South_of_Sawdust_10', 'South_of_Sawdust_9'], 1: ['Corbitt_Tract_Mid_1', 'Corbitt_Tract_Mid_2', 'Corbitt_Tract_Mid_4', 'Corbitt_Tract_Mid_5', 'Flat_Tub_789_1', 'Flat_Tub_789_2', 'Flat_Tub_789_3', 'Flat_Tub_789_4', 'Flat_Tub_789_5', 'Ricketson_Tract_SW_1', 'Ricketson_Tract_SW_2', 'Ricketson_Tract_SW_3', 'Ricketson_Tract_SW_4', 'Ricketson_Tract_SW_5', 'South_of_Sawdust_3', 'South_of_Sawdust_4', 'South_of_Sawdust_7'], 2: ['Flat_Tub_13_S_2', 'Flat_Tub_13_S_4', 'Flat_Tub_13_S_5', 'Flat_Tub_13_S_6']}
#
# Kmeans clustering: iter=2, K=3, mincov=0.7, minmap={0: 0.5, 1: 0.5, 2: 0.5}
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 164932
# Filtered (minmap): 161388
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 169386
# Sites after filtering: 25843
# Sites containing missing values: 20235 (78.30%)
# Missing values in SNP matrix: 89754 (10.52%)
# SNPs (total): 25843
# SNPs (unlinked): 4174
# Imputation: 'sampled'; (0, 1, 2) = 79.7%, 14.5%, 5.8%
# {0: ['Flat_Tub_13_S_2', 'Flat_Tub_13_S_4', 'Flat_Tub_13_S_5', 'Flat_Tub_13_S_6'], 1: ['Corbitt_Tract_Mid_1', 'Corbitt_Tract_Mid_2', 'Corbitt_Tract_Mid_4', 'Corbitt_Tract_Mid_5', 'Flat_Tub_789_1', 'Flat_Tub_789_2', 'Flat_Tub_789_3', 'Flat_Tub_789_4', 'Flat_Tub_789_5', 'Ricketson_Tract_SW_1', 'Ricketson_Tract_SW_2', 'Ricketson_Tract_SW_3', 'Ricketson_Tract_SW_4', 'Ricketson_Tract_SW_5', 'South_of_Sawdust_3', 'South_of_Sawdust_4', 'South_of_Sawdust_7'], 2: ['Arch_Cave_East_1', 'Arch_Cave_East_2', 'Arch_Cave_East_4', 'Arch_Cave_East_5', 'Corbitt_Tract_1', 'Corbitt_Tract_10', 'Corbitt_Tract_11', 'Corbitt_Tract_12', 'Corbitt_Tract_8', 'Corbitt_Tract_Mid_3', 'South_of_Sawdust_10', 'South_of_Sawdust_9']}
#
# Kmeans clustering: iter=3, K=3, mincov=0.6, minmap={0: 0.5, 1: 0.5, 2: 0.5}
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 152505
# Filtered (minmap): 161388
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 165070
# Sites after filtering: 30159
# Sites containing missing values: 24551 (81.41%)
# Missing values in SNP matrix: 138565 (13.92%)
# SNPs (total): 30159
# SNPs (unlinked): 4751
# Imputation: 'sampled'; (0, 1, 2) = 79.3%, 14.7%, 6.0%
# {0: ['Flat_Tub_13_S_2', 'Flat_Tub_13_S_4', 'Flat_Tub_13_S_5', 'Flat_Tub_13_S_6'], 1: ['Corbitt_Tract_Mid_1', 'Corbitt_Tract_Mid_2', 'Corbitt_Tract_Mid_4', 'Corbitt_Tract_Mid_5', 'Flat_Tub_789_1', 'Flat_Tub_789_2', 'Flat_Tub_789_3', 'Flat_Tub_789_4', 'Flat_Tub_789_5', 'Ricketson_Tract_SW_1', 'Ricketson_Tract_SW_2', 'Ricketson_Tract_SW_3', 'Ricketson_Tract_SW_4', 'Ricketson_Tract_SW_5', 'South_of_Sawdust_3', 'South_of_Sawdust_4', 'South_of_Sawdust_7'], 2: ['Arch_Cave_East_1', 'Arch_Cave_East_2', 'Arch_Cave_East_4', 'Arch_Cave_East_5', 'Corbitt_Tract_1', 'Corbitt_Tract_10', 'Corbitt_Tract_11', 'Corbitt_Tract_12', 'Corbitt_Tract_8', 'Corbitt_Tract_Mid_3', 'South_of_Sawdust_10', 'South_of_Sawdust_9']}
#
# Kmeans clustering: iter=4, K=3, mincov=0.5, minmap={0: 0.5, 1: 0.5, 2: 0.5}
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 140479
# Filtered (minmap): 161388
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 164168
# Sites after filtering: 31061
# Sites containing missing values: 25453 (81.95%)
# Missing values in SNP matrix: 151713 (14.80%)
# SNPs (total): 31061
# SNPs (unlinked): 4869
# Imputation: 'sampled'; (0, 1, 2) = 79.3%, 14.7%, 6.0%

# %%
# run and draw results for kmeans clustering into 7 groups
pca3.run(nreplicates=25, seed=123)
pca3.draw(0, 1)
# Out:
# Subsampling SNPs: 4869/31061
# (<toyplot.canvas.Canvas at 0x10c6d1280>,
#  <toyplot.coordinates.Cartesian at 0x10c6d1100>)
# <div class="toyplot" id="te1c3c2605bb84d23acf3bd270e1bb5f2" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t0893495230464bee9981b884ed6f3fa6"><g class="toyplot-coordinates-Cartesian" id="t92f14539342d47a78b1a46129e52f119"><clipPath id="t34398086e4f44fb6a8c00608b44edb8c"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t34398086e4f44fb6a8c00608b44edb8c)"><g class="toyplot-mark-Point" id="t7e390858bd5a48fdbac67511adc2216c"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(261.8091515245432, 239.71299036263989)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.65100811946877, 241.9494749383184)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(257.984256444312, 244.09399302509237)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(262.30059650372226, 243.575924391684)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.5622508108075, 240.59105741949244)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(209.83396009208673, 229.58038026145155)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(216.3173084978646, 232.55426861902058)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.6137521185073, 237.1839961054593)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(217.70658077634442, 235.56948547692986)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(74.95134021708208, 210.32852061783194)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(77.34998361575279, 213.62738086536746)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(202.81458263235172, 234.6535673668479)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(76.31893221109178, 210.1867327714058)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(73.76382066706424, 211.06571089886162)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="t ...

# %%
# run and draw results for kmeans clustering into 7 groups
pca3.run(nreplicates=25, seed=123)
pca3.draw(0, 2)
# Out:
# Subsampling SNPs: 4869/31061
# (<toyplot.canvas.Canvas at 0x176f62e20>,
#  <toyplot.coordinates.Cartesian at 0x177e2d400>)
# <div class="toyplot" id="t03fb2616f7684fd09888d96a54990589" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="tb90d9cbfc1de4bf0b98f3f9b8a9da4b9"><g class="toyplot-coordinates-Cartesian" id="t81e64629252f4d7bb2dfd53b700b8c50"><clipPath id="tdd1e535116b14f76adbe7162ceeed0f4"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#tdd1e535116b14f76adbe7162ceeed0f4)"><g class="toyplot-mark-Point" id="t817b84419cc543b98ced9aa5ff41b82c"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(261.8091515245432, 164.07443829163964)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.65100811946877, 169.68991612827998)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(257.984256444312, 167.8674041590748)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(262.30059650372226, 165.86080184157825)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.5622508108075, 155.2632931114476)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(209.83396009208673, 144.004597802996)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(216.3173084978646, 147.69968424375384)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(263.6137521185073, 156.71464834192807)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(217.70658077634442, 147.9495915458827)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(74.95134021708208, 64.28258252192546)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(77.34998361575279, 76.02615035374576)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(202.81458263235172, 112.53786787759444)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(76.31893221109178, 61.44621575385856)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(73.76382066706424, 67.38099064596943)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="tran ...

# %%
# run and draw results for kmeans clustering into 7 groups
pca3.run(nreplicates=25, seed=123)
pca3.draw(1, 2)
# Out:
# Subsampling SNPs: 4869/31061
# (<toyplot.canvas.Canvas at 0x1746d63d0>,
#  <toyplot.coordinates.Cartesian at 0x177eb7e50>)
# <div class="toyplot" id="te3956f7045184668978a767e275c03d7" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t0a3c4d718f0148e88ea9ed97c5aae4c9"><g class="toyplot-coordinates-Cartesian" id="t0762b233af9a4d93bcc20e96d8b7314d"><clipPath id="t651b7885b6de4146a7badf0e189dc135"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t651b7885b6de4146a7badf0e189dc135)"><g class="toyplot-mark-Point" id="tcdd364a793e94ea9ac712302210094c2"><g class="toyplot-Series"><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(61.31571060109611, 164.07443829163964)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(58.855577567849764, 169.68991612827998)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(56.496607672398405, 167.8674041590748)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(57.0664831691476, 165.86080184157825)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(60.34983683855832, 155.2632931114476)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(72.4615817124033, 144.004597802996)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(69.19030451907736, 147.69968424375384)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(64.09760428399477, 156.71464834192807)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(65.87356597537718, 147.9495915458827)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(93.63862732038488, 64.28258252192546)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(90.00988104809579, 76.02615035374576)"><circle r="5.0"></circle></g><g style="fill:rgb(100%,100%,74.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(66.88107589646732, 112.53786787759444)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(93.79459395145363, 61.44621575385856)"><circle r="5.0"></circle></g><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translate(92.82771801125219, 67.38099064596943)"><circle r="5.0"></circle></g><g style="fill:rgb(62%,0.4%,25.9%);fill-opacity:0.036000000000000004;opacity:1.0;stroke:none" class="toyplot-Datum" transform="translat ...

# %%
# .missing is a pandas DataFrame
pca3.missing.sort_values(by="missing")
# Out:
#                       missing
# Corbitt_Tract_Mid_3      0.11
# Corbitt_Tract_Mid_2      0.12
# South_of_Sawdust_3       0.12
# Corbitt_Tract_10         0.12
# Corbitt_Tract_8          0.12
# Corbitt_Tract_11         0.13
# Corbitt_Tract_Mid_1      0.13
# Flat_Tub_789_3           0.13
# Ricketson_Tract_SW_2     0.14
# Ricketson_Tract_SW_5     0.14
# Corbitt_Tract_Mid_4      0.14
# Flat_Tub_789_4           0.14
# Corbitt_Tract_12         0.14
# South_of_Sawdust_4       0.15
# Ricketson_Tract_SW_4     0.15
# Flat_Tub_789_1           0.15
# Flat_Tub_789_2           0.15
# Arch_Cave_East_5         0.16
# Arch_Cave_East_2         0.16
# Flat_Tub_789_5           0.16
# Arch_Cave_East_1         0.16
# South_of_Sawdust_10      0.17
# Flat_Tub_13_S_5          0.17
# Flat_Tub_13_S_6          0.17
# Ricketson_Tract_SW_3     0.18
# Flat_Tub_13_S_2          0.18
# Corbitt_Tract_Mid_5      0.18
# Corbitt_Tract_1          0.18
# Arch_Cave_East_4         0.18
# Ricketson_Tract_SW_1     0.21
# Flat_Tub_13_S_4          0.21
# South_of_Sawdust_7       0.22
# South_of_Sawdust_9       0.22

# %%
import os
print(os.getcwd())
# Out:
# /Users/peter/scripts

# %%
import ipyrad.analysis as ipa
import toyplot

# %%
# the path to your .snps.hdf5 database file
data = "~/Documents/Box/Isoetes/GBS/Broxton-strict.snps.hdf5"

# %%
# group individuals into populations
imap = {
    "Diploid": ["Ricketson_Tract_SW_4", "South_of_Sawdust_4", "Flat_Tub_789_3", "Flat_Tub_789_2", "Flat_Tub_789_1", "Corbitt_Tract_Mid_5", "Ricketson_Tract_SW_3", "Flat_Tub_789_4", "Corbitt_Tract_Mid_2", "Corbitt_Tract_Mid_4", "Flat_Tub_789_5", "South_of_Sawdust_3", "Ricketson_Tract_SW_1", "Ricketson_Tract_SW_5", "South_of_Sawdust_7", "Corbitt_Tract_Mid_1", "Ricketson_Tract_SW_2"],
    "Triploid": ["Corbitt_Tract_8", "Corbitt_Tract_10", "Corbitt_Tract_Mid_3", "Corbitt_Tract_11", "South_of_Sawdust_10", "South_of_Sawdust_9"],
    "Tetraploid": ["Flat_Tub_13_S_4", "Corbitt_Tract_1", "Flat_Tub_13_S_6", "Flat_Tub_13_S_2", "Flat_Tub_13_S_5", "Corbitt_Tract_12", "Arch_Cave_East_2", "Arch_Cave_East_5", "Arch_Cave_East_1", "Arch_Cave_East_4"],
}

# require that 50% of samples have data in each group
minmap = {i: 0.75 for i in imap}

# %%
# init analysis object with input data and (optional) parameter options
struct = ipa.structure(
    name="Broxton",
    data=data,
    imap=imap,
    minmap=minmap,
    mincov=0.9,
)
# Out:
# 25 previous results loaded for run [Broxton]
# Samples: 33
# Sites before filtering: 195369
# Filtered (indels): 2751
# Filtered (bi-allel): 2403
# Filtered (mincov): 179658
# Filtered (minmap): 159134
# Filtered (subsample invariant): 19497
# Filtered (minor allele frequency): 0
# Filtered (combined): 180788
# Sites after filtering: 14441
# Sites containing missing values: 8833 (61.17%)
# Missing values in SNP matrix: 16464 (3.45%)
# SNPs (total): 14441
# SNPs (unlinked): 2540

# %%
struct.mainparams.burnin = 10000
struct.mainparams.numreps = 50000

# %%
struct.run(nreps=50, kpop=[2, 3, 4, 5], auto=False)
# Out:
# Encountered an Error.
# Message:
# ipcluster not found, use 'auto=True' or see docs.
# Traceback (most recent call last):
#   File "/Users/peter/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyrad/core/Parallel.py", line 172, in wait_for_connection
#     ipyclient = ipp.Client(**args)
#   File "/Users/peter/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyparallel/client/client.py", line 417, in __init__
#     raise IOError(msg)
# OSError: Connection file '~/.ipython/profile_default/security/ipcontroller-client.json' not found.
# You have attempted to connect to an IPython Cluster but no Controller could be found.
# Please double-check your configuration and ensure that a cluster is running.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/peter/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyrad/core/Parallel.py", line 302, in wrap_run
#     self.ipyclient = self.wait_for_connection()
#   File "/Users/peter/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyrad/core/Parallel.py", line 217, in wait_for_connection
#     raise IPyradError(
# ipyrad.assemble.utils.IPyradError:
# ipcluster not found, use 'auto=True' or see docs.

# %%
etable = struct.get_evanno_table([2, 3, 4, 5])
etable
# Out:
#    Nreps        lnPK     lnPPK  deltaK  estLnProbMean  estLnProbStdev
# 2      3       0.000       0.0   0.000     -44568.867         332.875
# 3      3 -155465.933  231290.0   1.346    -200034.800      171837.263
# 4      3   75824.067       0.0   0.000    -124210.733      141625.130

# %%
k = 3
table = struct.get_clumpp_table(k)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-466182637728> in <module>
#       1 k = 3
# ----> 2 table = struct.get_clumpp_table(k)
#
# ~/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyrad/analysis/structure.py in get_clumpp_table(self, kvalues, max_var_multiple, quiet)
#     567
#     568         if isinstance(kvalues, int):
# --> 569             return _get_clumpp_table(self, kvalues, max_var_multiple, quiet)
#     570         else:
#     571             tabledict = {}
#
# ~/opt/miniconda3/envs/ipyrad/lib/python3.8/site-packages/ipyrad/analysis/structure.py in _get_clumpp_table(self, kpop, max_var_multiple, quiet)
#     856
#     857     # call clumpp
# --> 858     proc = sps.Popen(cmd, stderr=sps.STDOUT, stdout=sps.PIPE)
#     859     comm = proc.communicate()
#     860
#
# ~/opt/miniconda3/envs/ipyrad/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     856                             encoding=encoding, errors=errors)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#     860                                 startupinfo, creationflags, shell,
#
# ~/opt/miniconda3/envs/ipyrad/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1702                     if errno_num != 0:
#    1703                         err_msg = os.strerror(errno_num)
# -> 1704                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705                 raise child_exception_type(err_msg)
#    1706
#
# OSError: [Errno 86] Bad CPU type in executable: '/Users/peter/opt/miniconda3/envs/ipyrad/bin/CLUMPP'
